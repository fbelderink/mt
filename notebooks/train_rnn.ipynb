# %%
import os

# %%
# !cd /content
# !rm -rf /content/mt

# %%
# clone if does not exist
if not os.path.isdir('/content/mt'):
    # !git clone https://github.com/fbelderink/mt.git
# %cd /content/mt
# !git pull
# !git checkout fb/dev
# !git pull
# Out:
# Cloning into 'mt'...
# remote: Enumerating objects: 1396, done.
# remote: Counting objects: 100% (1396/1396), done.
# remote: Compressing objects: 100% (669/669), done.
# remote: Total 1396 (delta 781), reused 1291 (delta 689), pack-reused 0
# Receiving objects: 100% (1396/1396), 3.62 MiB | 4.03 MiB/s, done.
# Resolving deltas: 100% (781/781), done.
# /content/mt
# Already up to date.
# Branch 'fb/dev' set up to track remote branch 'fb/dev' from 'origin'.
# Switched to a new branch 'fb/dev'
# Already up to date.

# %%
import training.train as train
from utils.ConfigLoader import ConfigLoader
from utils.model_hyperparameters import RNNModelHyperparameters
from utils.train_hyperparameters import RNNTrainHyperparameters
from google.colab import drive

# %%
import torch
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
drive_dir = '/content/drive'
drive.mount(drive_dir)

dataset_dir = os.path.join(drive_dir,'MyDrive/data/mt')

model_params = RNNModelHyperparameters(
    ConfigLoader("configs/rnn/config.yaml").get_config())

train_params = RNNTrainHyperparameters(
    ConfigLoader("configs/training/rnn_train_config.yaml").get_config())

train.train(os.path.join(dataset_dir,f"train7k_rnn.pt"),
            os.path.join(dataset_dir,f"val7k_rnn.pt"),
            model_params,
            train_params)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# training on cuda:0
# Number of Batches: 1813
# Batch Size: 16
# model name: None
# total number of trainable parameters: 10738662
# Layers:
# encoder: Encoder(
#   (embedding): Embedding(6798, 250, padding_idx=3)
#   (rnn): LSTM(250, 200, batch_first=True, bidirectional=True)
# )
# decoder: AttentionDecoder(
#   (embedding): Embedding(6462, 250, padding_idx=3)
#   (rnn): LSTM(250, 400, batch_first=True)
#   (attention): Attention(
#     (Q): Linear(in_features=400, out_features=400, bias=True)
#     (K): Linear(in_features=400, out_features=400, bias=True)
#     (V): Linear(in_features=400, out_features=400, bias=True)
#   )
#   (fc): Linear(in_features=800, out_features=6462, bias=True)
# )
#
# Starting Training:
#
# Epoch 1/20
# steps: 0, epoch: 1
# batch metrics: accuracy: 0.0, perplexity: 6441.774411693308, loss: 8.770559310913086
#
# validation results: accuracy: 0.12427862031942022, perplexity: 6003.5064833228535, loss: 8.700098991394043
#
# steps: 400, epoch: 1
# batch metrics: accuracy: 0.4248927038626609, perplexity: 38.03997356401304, loss: 3.6386375427246094
#
# validation results: accuracy: 0.4410146289088713, perplexity: 38.373888932098616, loss: 3.6473772525787354
#
# steps: 800, epoch: 1
# batch metrics: accuracy: 0.6183574879227053, perplexity: 11.288292607026785, loss: 2.4237661361694336
#
# validation results: accuracy: 0.5018789424238357, perplexity: 22.087333957817208, loss: 3.0950043201446533
#
# steps: 1200, epoch: 1
# batch metrics: accuracy: 0.5466666666666666, perplexity: 21.768851085432207, loss: 3.0804800987243652
#
# validation results: accuracy: 0.545631458864582, perplexity: 15.770412488664375, loss: 2.7581355571746826
#
# steps: 1600, epoch: 1
# batch metrics: accuracy: 0.5352697095435685, perplexity: 14.546459927533371, loss: 2.6773476600646973
#
# validation results: accuracy: 0.5709300764997987, perplexity: 12.803198403093253, loss: 2.5496950149536133
#
#
#  saving checkpoint at eval/checkpoints/2024-06-30-None/21_11_17.pth
#
# Epoch 2/20
# steps: 0, epoch: 2
# batch metrics: accuracy: 0.6779661016949152, perplexity: 5.395136394185984, loss: 1.6854978799819946
#
# validation results: accuracy: 0.5779090055026171, perplexity: 11.619163864326165, loss: 2.452655792236328
#
# steps: 400, epoch: 2
# batch metrics: accuracy: 0.6009174311926605, perplexity: 7.526167041233704, loss: 2.018385887145996
#
# validation results: accuracy: 0.5845524090726077, perplexity: 10.730948936526527, loss: 2.3731319904327393
#
# steps: 800, epoch: 2
# batch metrics: accuracy: 0.6035242290748899, perplexity: 7.698053190172686, loss: 2.0409674644470215
#
# validation results: accuracy: 0.6018655214065226, perplexity: 9.524352032016209, loss: 2.253851890563965
#
# steps: 1200, epoch: 2
# batch metrics: accuracy: 0.6222222222222222, perplexity: 6.556957252377033, loss: 1.8805266618728638
#
# validation results: accuracy: 0.607636558851161, perplexity: 8.848804404482014, loss: 2.1802823543548584
#
# steps: 1600, epoch: 2
# batch metrics: accuracy: 0.6593886462882096, perplexity: 6.687442276265797, loss: 1.9002314805984497
#
# validation results: accuracy: 0.6198496846060931, perplexity: 8.214504882345507, loss: 2.1059014797210693
#
#
#  saving checkpoint at eval/checkpoints/2024-06-30-None/21_14_10.pth
#
# Epoch 3/20
# steps: 0, epoch: 3
# batch metrics: accuracy: 0.6896551724137931, perplexity: 4.5922208674819105, loss: 1.5243637561798096
#
# validation results: accuracy: 0.6221983626358878, perplexity: 7.963599346102777, loss: 2.074881076812744
#
# steps: 400, epoch: 3
# batch metrics: accuracy: 0.6626016260162602, perplexity: 4.409276630455668, loss: 1.4837106466293335
#
# validation results: accuracy: 0.6226009931552812, perplexity: 8.015529472796157, loss: 2.081380844116211
#
# HALF LR: previous lr: 0.001, new lr: 0.0005
#
# steps: 800, epoch: 3
# batch metrics: accuracy: 0.726890756302521, perplexity: 3.214811091871319, loss: 1.1677685976028442
#
# validation results: accuracy: 0.6300496577640585, perplexity: 7.522528922153735, loss: 2.017902374267578
#
# steps: 1200, epoch: 3
# batch metrics: accuracy: 0.7254901960784313, perplexity: 3.217077577815189, loss: 1.1684733629226685
#
# validation results: accuracy: 0.632733861226681, perplexity: 7.366041206100227, loss: 1.9968804121017456
#
# steps: 1600, epoch: 3
# batch metrics: accuracy: 0.7172995780590717, perplexity: 3.6854453904255986, loss: 1.3043913841247559
#
# validation results: accuracy: 0.6375654274594014, perplexity: 7.188807899534504, loss: 1.9725253582000732
#
#
#  saving checkpoint at eval/checkpoints/2024-06-30-None/21_17_03.pth
#
# Epoch 4/20
# steps: 0, epoch: 4
# batch metrics: accuracy: 0.7488372093023256, perplexity: 2.737371902806339, loss: 1.0069983005523682
#
# validation results: accuracy: 0.6376996376325326, perplexity: 7.136415054005733, loss: 1.9652105569839478
#
# steps: 400, epoch: 4
# batch metrics: accuracy: 0.7576923076923077, perplexity: 2.7814180880537394, loss: 1.022960901260376
#
# validation results: accuracy: 0.6379680579787947, perplexity: 7.278987616451754, loss: 1.9849917888641357
#
# HALF LR: previous lr: 0.0005, new lr: 0.00025
#
# steps: 800, epoch: 4
# batch metrics: accuracy: 0.7898832684824902, perplexity: 2.2751162279972266, loss: 0.8220311403274536
#
# validation results: accuracy: 0.6370956918534425, perplexity: 7.168643385815461, loss: 1.9697164297103882
#
# steps: 1200, epoch: 4
# batch metrics: accuracy: 0.8046511627906977, perplexity: 2.1685536577009747, loss: 0.7740604281425476
#
# validation results: accuracy: 0.6379680579787947, perplexity: 7.051268239889095, loss: 1.9532074928283691
#
# steps: 1600, epoch: 4
# batch metrics: accuracy: 0.8457943925233645, perplexity: 1.9615925307733262, loss: 0.6737566590309143
#
# validation results: accuracy: 0.6405180512682861, perplexity: 7.016501402224312, loss: 1.948264718055725
#
#
#  saving checkpoint at eval/checkpoints/2024-06-30-None/21_20_00.pth
#
# Epoch 5/20
# steps: 0, epoch: 5
# batch metrics: accuracy: 0.8558558558558559, perplexity: 2.24003327197833, loss: 0.8064907193183899
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f01a0b0bac0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1443, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# validation results: accuracy: 0.6402496309220239, perplexity: 7.018774356444067, loss: 1.9485886096954346
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1132         try:
# -> 1133             data = self._data_queue.get(timeout=timeout)
#    1134             return (True, data)
#
# /usr/lib/python3.10/multiprocessing/queues.py in get(self, block, timeout)
#     121         # unserialize the data after having released the lock
# --> 122         return _ForkingPickler.loads(res)
#     123
#
# /usr/local/lib/python3.10/dist-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     494 def rebuild_storage_fd(cls, df, size):
# --> 495     fd = df.detach()
#     496     try:
#
# /usr/lib/python3.10/multiprocessing/resource_sharer.py in detach(self)
#      56             '''Get the fd.  This should only be called once.'''
# ---> 57             with _resource_sharer.get_connection(self._id) as conn:
#      58                 return reduction.recv_handle(conn)
#
# /usr/lib/python3.10/multiprocessing/resource_sharer.py in get_connection(ident)
#      85         address, key = ident
# ---> 86         c = Client(address, authkey=process.current_process().authkey)
#      87         c.send((key, os.getpid()))
#
# /usr/lib/python3.10/multiprocessing/connection.py in Client(address, family, authkey)
#     501     else:
# --> 502         c = SocketClient(address)
#     503
#
# /usr/lib/python3.10/multiprocessing/connection.py in SocketClient(address)
#     629         s.setblocking(True)
# --> 630         s.connect(address)
#     631         return Connection(s.detach())
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-38939f9a302a> in <cell line: 12>()
#      10     ConfigLoader("configs/training/rnn_train_config.yaml").get_config())
#      11
# ---> 12 train.train(os.path.join(dataset_dir,f"train7k_rnn.pt"),
#      13             os.path.join(dataset_dir,f"val7k_rnn.pt"),
#      14             model_params,
#
# /content/mt/training/train.py in train(train_path, validation_path, model_params, train_params, model_name)
#      76         print(f"Epoch {epoch}/{train_params.max_epochs}")
#      77
# ---> 78         total_steps, epoch_loss = train_epoch(model,
#      79                                               train_dataloader, validation_dataloader,
#      80                                               optimizers,
#
# /content/mt/training/train.py in train_epoch(model, train_dataloader, validation_dataloader, optimizers, train_params, epoch_num, total_steps, checkpoint_rate, do_checkpointing)
#      97     previous_val_ppl = 0
#      98
# ---> 99     for source, target, label in train_dataloader:
#     100         source = source.to(device)
#     101         target = target.to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1327
#    1328             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329             idx, data = self._get_data()
#    1330             self._tasks_outstanding -= 1
#    1331             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1293         else:
#    1294             while True:
# -> 1295                 success, data = self._try_get_data()
#    1296                 if success:
#    1297                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1144             if len(failed_workers) > 0:
#    1145                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1146                 raise RuntimeError(f'DataLoader worker (pid(s) {pids_str}) exited unexpectedly') from e
#    1147             if isinstance(e, queue.Empty):
#    1148                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 6389, 6391) exited unexpectedly

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-ec5b4689-1f4f-b910-6e1e-94af4dede7be)

# %%
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')

# %%
# !zip -r {dataset_dir}/checkpoints.zip eval/checkpoints/{date}-None/
# Out:
# 	zip warning: name not matched: eval/checkpoints/{date}-None/
#
# zip error: Nothing to do! (try: zip -r {dataset_dir}/checkpoints.zip . -i eval/checkpoints/{date}-None/)
