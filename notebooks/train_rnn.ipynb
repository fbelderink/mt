# %%
import os

# %%
# clone if does not exist
if os.path.isdir('/content/mt'):
  # %cd /content
  # !rm -rf /content/mt
# !git clone https://github.com/fbelderink/mt.git
# %cd /content/mt
# !git pull
# !git checkout fb/dev
# !git pull
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'mt': No such file or directory
# [Errno 2] No such file or directory: '/content/mt'
# /content/mt
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: Unable to read current working directory: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: Unable to read current working directory: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: Unable to read current working directory: No such file or directory

# %%
import training.train as train
from utils.ConfigLoader import ConfigLoader
from utils.model_hyperparameters import RNNModelHyperparameters
from utils.train_hyperparameters import RNNTrainHyperparameters
from google.colab import drive

# %%
import torch
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')
time = datetime.today().strftime('%H_%M_%S')

# %%
drive_dir = '/content/drive'
drive.mount(drive_dir)

dataset_dir = os.path.join(drive_dir,'MyDrive/data/mt')

model_params = RNNModelHyperparameters(
    ConfigLoader("configs/rnn/config.yaml").get_config())

train_params = RNNTrainHyperparameters(
    ConfigLoader("configs/training/rnn_train_config.yaml").get_config())

train.train(os.path.join(dataset_dir,f"train7k_rnn.pt"),
            os.path.join(dataset_dir,f"val7k_rnn.pt"),
            model_params,
            train_params,
            model_name=time)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# training on cuda:0
# Number of Batches: 1813
# Batch Size: 16
# model name: 16_24_25
# total number of trainable parameters: 18644563
# Layers:
# encoder: Encoder(
#   (embedding): Embedding(6798, 300, padding_idx=3)
#   (rnn): LSTM(300, 350, batch_first=True, bidirectional=True)
# )
# decoder: AttentionDecoder(
#   (embedding): Embedding(6462, 300, padding_idx=3)
#   (rnn): LSTM(300, 700, batch_first=True)
#   (attention): Attention(
#     (Wa): Linear(in_features=700, out_features=700, bias=True)
#     (Ua): Linear(in_features=700, out_features=700, bias=True)
#     (activation): Tanh()
#     (Va): Linear(in_features=700, out_features=1, bias=True)
#   )
#   (fc): Linear(in_features=1400, out_features=6462, bias=True)
# )
#
# Starting Training:
#
# Epoch 1/5
# steps: 0, epoch: 1
# batch metrics: accuracy: 0.0, perplexity: 6483.202690876442, loss: 8.776969909667969
#
# validation results: accuracy: 0.017380217420480473, perplexity: 6308.425617477961, loss: 8.749641418457031
#
# steps: 400, epoch: 1
# batch metrics: accuracy: 0.4088888888888889, perplexity: 40.277016355715645, loss: 3.6957809925079346
#
# validation results: accuracy: 0.3842437256744061, perplexity: 55.6366800651648, loss: 4.018842697143555
#
# steps: 800, epoch: 1
# batch metrics: accuracy: 0.44075829383886256, perplexity: 25.819175902314107, loss: 3.251117467880249
#
# validation results: accuracy: 0.4632264125620722, perplexity: 31.45425443843859, loss: 3.4485342502593994
#
# steps: 1200, epoch: 1
# batch metrics: accuracy: 0.529126213592233, perplexity: 15.180170670647016, loss: 2.7199900150299072
#
# validation results: accuracy: 0.4975171117970742, perplexity: 22.69189578423294, loss: 3.1220078468322754
#
# steps: 1600, epoch: 1
# batch metrics: accuracy: 0.5194805194805194, perplexity: 17.720366236915, loss: 2.8747146129608154
#
# validation results: accuracy: 0.5267078244530935, perplexity: 18.04785047351048, loss: 2.89302659034729
#
#
#  saving checkpoint at eval/checkpoints/2024-07-07-16_24_25/16_33_42.pth
#
# Epoch 2/5
# steps: 0, epoch: 2
# batch metrics: accuracy: 0.4590909090909091, perplexity: 17.76437205327828, loss: 2.877194881439209
#
# validation results: accuracy: 0.5421419943631727, perplexity: 16.275019182297612, loss: 2.7896313667297363
#
# steps: 400, epoch: 2
# batch metrics: accuracy: 0.51440329218107, perplexity: 19.34959095367183, loss: 2.9626712799072266
#
# validation results: accuracy: 0.559388001610522, perplexity: 14.270511241870267, loss: 2.6581952571868896
#
# steps: 800, epoch: 2
# batch metrics: accuracy: 0.5462962962962963, perplexity: 15.209536554724014, loss: 2.7219226360321045
#
# validation results: accuracy: 0.5718695477117165, perplexity: 12.768778744955304, loss: 2.5470030307769775
#
# steps: 1200, epoch: 2
# batch metrics: accuracy: 0.5795918367346938, perplexity: 9.311067947949919, loss: 2.23120379447937
#
# validation results: accuracy: 0.5854918802845256, perplexity: 11.50646992269166, loss: 2.4429094791412354
#
# steps: 1600, epoch: 2
# batch metrics: accuracy: 0.634703196347032, perplexity: 6.846376439228482, loss: 1.9237195253372192
#
# validation results: accuracy: 0.59736948060663, perplexity: 10.540006056695313, loss: 2.355178117752075
#
#
#  saving checkpoint at eval/checkpoints/2024-07-07-16_24_25/16_37_47.pth
#
# Epoch 3/5
# steps: 0, epoch: 3
# batch metrics: accuracy: 0.6584362139917695, perplexity: 6.564695462155542, loss: 1.8817061185836792
#
# validation results: accuracy: 0.5962286941350154, perplexity: 10.256140176502099, loss: 2.327876567840576
#
# steps: 400, epoch: 3
# batch metrics: accuracy: 0.6037037037037037, perplexity: 7.3056311001970835, loss: 1.9886454343795776
#
# validation results: accuracy: 0.6019326264930882, perplexity: 9.77189354668678, loss: 2.279510259628296
#
# steps: 800, epoch: 3
# batch metrics: accuracy: 0.6150442477876106, perplexity: 6.519276278582944, loss: 1.8747633695602417
#
# validation results: accuracy: 0.6041470943497517, perplexity: 9.392675213340592, loss: 2.2399301528930664
#
# steps: 1200, epoch: 3
# batch metrics: accuracy: 0.576, perplexity: 8.632116146028174, loss: 2.155489683151245
#
# validation results: accuracy: 0.6105891826600456, perplexity: 8.909824385596506, loss: 2.187154531478882
#
# steps: 1600, epoch: 3
# batch metrics: accuracy: 0.630901287553648, perplexity: 6.5026872166537775, loss: 1.8722155094146729
#
# validation results: accuracy: 0.6170983760569051, perplexity: 8.478426202193006, loss: 2.1375248432159424
#
#
#  saving checkpoint at eval/checkpoints/2024-07-07-16_24_25/16_41_51.pth
#
# Epoch 4/5
# steps: 0, epoch: 4
# batch metrics: accuracy: 0.756198347107438, perplexity: 3.3475395318277417, loss: 1.2082256078720093
#
# validation results: accuracy: 0.6162260099315529, perplexity: 8.330683670690005, loss: 2.119945526123047
#
# steps: 400, epoch: 4
# batch metrics: accuracy: 0.6855895196506551, perplexity: 3.3544467567144616, loss: 1.2102868556976318
#
# validation results: accuracy: 0.6197825795195275, perplexity: 8.270180667306525, loss: 2.112656354904175
#
# steps: 800, epoch: 4
# batch metrics: accuracy: 0.6493506493506493, perplexity: 5.245368066697791, loss: 1.6573454141616821
#
# validation results: accuracy: 0.6234062541940679, perplexity: 8.09902326013, loss: 2.0917434692382812
#
# steps: 1200, epoch: 4
# batch metrics: accuracy: 0.7066666666666667, perplexity: 4.3279421809689875, loss: 1.4650921821594238
#
# validation results: accuracy: 0.6263588780029526, perplexity: 7.862611228943918, loss: 2.0621187686920166
#
# steps: 1600, epoch: 4
# batch metrics: accuracy: 0.6607929515418502, perplexity: 4.793185286106579, loss: 1.567195177078247
#
# validation results: accuracy: 0.6265601932626493, perplexity: 7.635238760151411, loss: 2.0327742099761963
#
#
#  saving checkpoint at eval/checkpoints/2024-07-07-16_24_25/16_45_56.pth
#
# Epoch 5/5
# steps: 0, epoch: 5
# batch metrics: accuracy: 0.8486486486486486, perplexity: 1.8962214452585084, loss: 0.6398631930351257
#
# validation results: accuracy: 0.6297812374177962, perplexity: 7.544373253879933, loss: 2.0208020210266113
#
# steps: 400, epoch: 5
# batch metrics: accuracy: 0.7522935779816514, perplexity: 3.1876071480007746, loss: 1.1592705249786377
#
# validation results: accuracy: 0.6287075560327473, perplexity: 7.607843932873391, loss: 2.029179811477661
#
# HALF LR: previous lr: 0.00025, new lr: 0.000125
#
# steps: 800, epoch: 5
# batch metrics: accuracy: 0.803347280334728, perplexity: 2.2532329878212427, loss: 0.8123660683631897
#
# validation results: accuracy: 0.6328680713998122, perplexity: 7.387673303054779, loss: 1.9998128414154053
#
# steps: 1200, epoch: 5
# batch metrics: accuracy: 0.8080357142857143, perplexity: 2.4566511991654605, loss: 0.8987991213798523
#
# validation results: accuracy: 0.6350825392564756, perplexity: 7.361709931947222, loss: 1.996292233467102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0f3dbeb29d2a> in <cell line: 12>()
#      10     ConfigLoader("configs/training/rnn_train_config.yaml").get_config())
#      11
# ---> 12 train.train(os.path.join(dataset_dir,f"train7k_rnn.pt"),
#      13             os.path.join(dataset_dir,f"val7k_rnn.pt"),
#      14             model_params,
#
# /content/mt/training/train.py in train(train_path, validation_path, model_params, train_params, model_name)
#      76         print(f"Epoch {epoch}/{train_params.max_epochs}")
#      77
# ---> 78         total_steps, epoch_loss = train_epoch(model,
#      79                                               train_dataloader, validation_dataloader,
#      80                                               optimizers,
#
# /content/mt/training/train.py in train_epoch(model, train_dataloader, validation_dataloader, optimizers, train_params, epoch_num, total_steps, checkpoint_rate, do_checkpointing)
#     113             optimizer.step()
#     114
# --> 115         epoch_loss += loss.item()
#     116
#     117         # EVAL AND OPTIONAL FEATURES
#
# KeyboardInterrupt:

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-ec5b4689-1f4f-b910-6e1e-94af4dede7be)

# %%
# !zip -r {dataset_dir}/checkpoints.zip eval/checkpoints/
# Out:
#   adding: eval/checkpoints/ (stored 0%)
#   adding: eval/checkpoints/.gitignore (stored 0%)
#   adding: eval/checkpoints/2024-07-07-16_24_25/ (stored 0%)
#   adding: eval/checkpoints/2024-07-07-16_24_25/16_37_47.pth (deflated 7%)
#   adding: eval/checkpoints/2024-07-07-16_24_25/16_45_56.pth (deflated 7%)
#   adding: eval/checkpoints/2024-07-07-16_24_25/16_41_51.pth (deflated 7%)
#   adding: eval/checkpoints/2024-07-07-16_24_25/16_33_42.pth (deflated 7%)
